# %%
#general
import numpy as np
import pandas as pd
from datetime import datetime

# plotting
import seaborn as sns 
import plotly.express as px
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/DataSets/Indices.csv')

# %%
df.head()
# Out:
#   CountryName CountryCode Jurisdiction      Date  \
# 0   Argentina         ARG    NAT_TOTAL  20220101
# 1   Argentina         ARG    NAT_TOTAL  20220102
# 2   Argentina         ARG    NAT_TOTAL  20220103
# 3   Argentina         ARG    NAT_TOTAL  20220104
# 4   Argentina         ARG    NAT_TOTAL  20220105
#
#    StringencyIndex_NonVaccinated  StringencyIndex_NonVaccinated_ForDisplay  \
# 0                           53.7                                      53.7
# 1                           53.7                                      53.7
# 2                           53.7                                      53.7
# 3                           53.7                                      53.7
# 4                           53.7                                      53.7
#
#    StringencyIndex_Vaccinated  StringencyIndex_Vaccinated_ForDisplay  \
# 0                       29.63                                  29.63
# 1                       29.63                                  29.63
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6935 entries, 0 to 6934
# Data columns (total 30 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   CountryName                                         6935 non-null   object
#  1   CountryCode                                         6935 non-null   object
#  2   Jurisdiction                                        6935 non-null   object
#  3   Date                                                6935 non-null   int64
#  4   StringencyIndex_NonVaccinated                       6931 non-null   float64
#  5   StringencyIndex_NonVaccinated_ForDisplay            6931 non-null   float64
#  6   StringencyIndex_Vaccinated                          6931 non-null   float64
#  7   StringencyIndex_Vaccinated_ForDisplay               6931 non-null   float64
# ...

# %%
df['New_Date'] = df['Date'].astype(str).apply(lambda x: datetime.strptime(x, '%Y%m%d'))
df.head()
# Out:
#   CountryName CountryCode Jurisdiction      Date  \
# 0   Argentina         ARG    NAT_TOTAL  20220101
# 1   Argentina         ARG    NAT_TOTAL  20220102
# 2   Argentina         ARG    NAT_TOTAL  20220103
# 3   Argentina         ARG    NAT_TOTAL  20220104
# 4   Argentina         ARG    NAT_TOTAL  20220105
#
#    StringencyIndex_NonVaccinated  StringencyIndex_NonVaccinated_ForDisplay  \
# 0                           53.7                                      53.7
# 1                           53.7                                      53.7
# 2                           53.7                                      53.7
# 3                           53.7                                      53.7
# 4                           53.7                                      53.7
#
#    StringencyIndex_Vaccinated  StringencyIndex_Vaccinated_ForDisplay  \
# 0                       29.63                                  29.63
# 1                       29.63                                  29.63
# ...

# %%
df.dtypes
# Out:
# CountryName                                                   object
# CountryCode                                                   object
# Jurisdiction                                                  object
# Date                                                           int64
# StringencyIndex_NonVaccinated                                float64
# StringencyIndex_NonVaccinated_ForDisplay                     float64
# StringencyIndex_Vaccinated                                   float64
# StringencyIndex_Vaccinated_ForDisplay                        float64
# StringencyIndex_SimpleAverage                                float64
# StringencyIndex_SimpleAverage_ForDisplay                     float64
# StringencyIndex_WeightedAverage                              float64
# StringencyIndex_WeightedAverage_ForDisplay                   float64
# GovernmentResponseIndex_NonVaccinated                        float64
# GovernmentResponseIndex_NonVaccinated_ForDisplay             float64
# ...

# %%
df_con = df.groupby('CountryName')

# %%
df_con.first()
# Out:
#                CountryCode Jurisdiction      Date  \
# CountryName
# Argentina              ARG    NAT_TOTAL  20220101
# Australia              AUS    NAT_TOTAL  20220101
# Brazil                 BRA    NAT_TOTAL  20220101
# Canada                 CAN    NAT_TOTAL  20220101
# China                  CHN    NAT_TOTAL  20220101
# France                 FRA    NAT_TOTAL  20220101
# Germany                DEU    NAT_TOTAL  20220101
# India                  IND    NAT_TOTAL  20220101
# Indonesia              IDN    NAT_TOTAL  20220101
# Italy                  ITA    NAT_TOTAL  20220101
# Japan                  JPN    NAT_TOTAL  20220101
# Mexico                 MEX    NAT_TOTAL  20220101
# Russia                 RUS    NAT_TOTAL  20220101
# Saudi Arabia           SAU    NAT_TOTAL  20220101
# South Africa           ZAF    NAT_TOTAL  20220101
# South Korea            KOR    NAT_TOTAL  20220101
# Turkey                 TUR    NAT_TOTAL  20220101
# ...

# %%
df_con.get_group('Argentina')
# Out:
#     CountryName CountryCode Jurisdiction      Date  \
# 0     Argentina         ARG    NAT_TOTAL  20220101
# 1     Argentina         ARG    NAT_TOTAL  20220102
# 2     Argentina         ARG    NAT_TOTAL  20220103
# 3     Argentina         ARG    NAT_TOTAL  20220104
# 4     Argentina         ARG    NAT_TOTAL  20220105
# ..          ...         ...          ...       ...
# 360   Argentina         ARG    NAT_TOTAL  20221227
# 361   Argentina         ARG    NAT_TOTAL  20221228
# 362   Argentina         ARG    NAT_TOTAL  20221229
# 363   Argentina         ARG    NAT_TOTAL  20221230
# 364   Argentina         ARG    NAT_TOTAL  20221231
#
#      StringencyIndex_NonVaccinated  StringencyIndex_NonVaccinated_ForDisplay  \
# 0                             53.7                                      53.7
# 1                             53.7                                      53.7
# 2                             53.7                                      53.7
# ...

# %%
df_con.dtypes
# Out:
#                CountryCode Jurisdiction   Date StringencyIndex_NonVaccinated  \
# CountryName
# Argentina           object       object  int64                       float64
# Australia           object       object  int64                       float64
# Brazil              object       object  int64                       float64
# Canada              object       object  int64                       float64
# China               object       object  int64                       float64
# France              object       object  int64                       float64
# Germany             object       object  int64                       float64
# India               object       object  int64                       float64
# Indonesia           object       object  int64                       float64
# Italy               object       object  int64                       float64
# Japan               object       object  int64                       float64
# ...

# %% [markdown]
# **StringencyIndex_WeightedAverage_ForDisplay Group 1**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Australia'),
    label='Australia',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Canada'),
    label='Canada'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Saudi Arabia'),
    label='Saudi Arabia'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('United States'),
    label='United States'
)

plt.legend()
plt.xticks(fontsize=12, rotation=25)
plt.yticks(fontsize=12)
plt.title('Country wise StringencyIndex_WeightedAverage - Group 1',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('StringencyIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **StringencyIndex_WeightedAverage_ForDisplay Group 2**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('India'),
    label='India',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Russia'),
    label='Russia'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('South Africa'),
    label='South Africa'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Turkey'),
    label='Turkey'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise StringencyIndex_WeightedAverage - Group 2',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('StringencyIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **StringencyIndex_WeightedAverage_ForDisplay Group 3**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Argentina'),
    label='Argentina',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Brazil'),
    label='Brazil'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Mexico'),
    label='Mexico'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise StringencyIndex_WeightedAverage - Group 3',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('StringencyIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **StringencyIndex_WeightedAverage_ForDisplay Group 4**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('France'),
    label='France',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Germany'),
    label='Germany'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Italy'),
    label='Italy'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('United Kingdom'),
    label='United Kingdom'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise StringencyIndex_WeightedAverage - Group 4',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('StringencyIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **StringencyIndex_WeightedAverage_ForDisplay Group 5**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('China'),
    label='China',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Indonesia'),
    label='Indonesia'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Japan'),
    label='Japan'
)

sns.lineplot(
    x='New_Date',
    y='StringencyIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('South Korea'),
    label='South Korea'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise StringencyIndex_WeightedAverage - Group 5',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('StringencyIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **GovernmentResponseIndex_WeightedAverage_ForDisplay for Group 1**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])
sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Australia'),
    label='Australia',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Canada'),
    label='Canada'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Saudi Arabia'),
    label='Saudi Arabia'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('United States'),
    label='United States'
)

plt.legend()
plt.xticks(rotation=25,fontsize=10)
plt.yticks(fontsize=10)
plt.title('Country wise GovenmentResponseIndex_WeightedAverage - Group 1',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('GovenmentResponseIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **GovernmentResponseIndex_WeightedAverage_ForDisplay for Group 2**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('India'),
    label='India',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Russia'),
    label='Russia'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('South Africa'),
    label='South Africa'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Turkey'),
    label='Turkey'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise GovernmentResponseIndex_WeightedAverage - Group 2',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('GovernmentResponseIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **GovernmentResponseIndex_WeightedAverage_ForDisplay for Group 3**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Argentina'),
    label='Argentina',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Brazil'),
    label='Brazil'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Mexico'),
    label='Mexico'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise GovernmentResponseIndex_WeightedAverage - Group 3',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('GovernmentResponseIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **GovernmentResponseIndex_WeightedAverage_ForDisplay for Group 4**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('France'),
    label='France',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Germany'),
    label='Germany'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Italy'),
    label='Italy'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('United Kingdom'),
    label='United Kingdom'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise GovernmentResponseIndex_WeightedAverage - Group 4',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('GovernmentResponseIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **GovernmentResponseIndex_WeightedAverage_ForDisplay for Group 5**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('China'),
    label='China',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Indonesia'),
    label='Indonesia'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Japan'),
    label='Japan'
)

sns.lineplot(
    x='New_Date',
    y='GovernmentResponseIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('South Korea'),
    label='South Korea'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise GovernmentResponseIndex_WeightedAverage - Group 5',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('GovernmentResponseIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **ContainmentHealthIndex_WeightedAverage_ForDisplay Group 1**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Australia'),
    label='Australia',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Canada'),
    label='Canada'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Saudi Arabia'),
    label='Saudi Arabia'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('United States'),
    label='United States'
)

plt.legend()
plt.xticks(rotation=25,fontsize=10)
plt.yticks(fontsize=10)
plt.title('Country wise ContainmentHealthIndex_WeightedAverage - Group 1',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('ContainmentHealthIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **ContainmentHealthIndex_WeightedAverage_ForDisplay Group 2**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('India'),
    label='India',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Russia'),
    label='Russia'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('South Africa'),
    label='South Africa'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Turkey'),
    label='Turkey'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise ContainmentHealthIndex_WeightedAverage - Group 2',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('ContainmentHealthIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **ContainmentHealthIndex_WeightedAverage_ForDisplay Group 3**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Argentina'),
    label='Argentina',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Brazil'),
    label='Brazil'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Mexico'),
    label='Mexico'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise ContainmentHealthIndex_WeightedAverage - Group 3',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('ContainmentHealthIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **ContainmentHealthIndex_WeightedAverage_ForDisplay Group 4**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('France'),
    label='France',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Germany'),
    label='Germany'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Italy'),
    label='Italy'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('United Kingdom'),
    label='United Kingdom'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise ContainmentHealthIndex_WeightedAverage - Group 4',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('ContainmentHealthIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **ContainmentHealthIndex_WeightedAverage_ForDisplay Group 5**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('China'),
    label='China',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Indonesia'),
    label='Indonesia'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('Japan'),
    label='Japan'
)

sns.lineplot(
    x='New_Date',
    y='ContainmentHealthIndex_WeightedAverage_ForDisplay',
    data=df_con.get_group('South Korea'),
    label='South Korea'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise ContainmentHealthIndex_WeightedAverage - Group 5',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('ContainmentHealthIndex_WeightedAverage',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **EconomicSupportIndex_ForDisplay Group 1**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Australia'),
    label='Australia',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Canada'),
    label='Canada'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Saudi Arabia'),
    label='Saudi Arabia'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('United States'),
    label='United States'
)

plt.legend()
plt.xticks(rotation=25,fontsize=10)
plt.yticks(fontsize=10)
plt.title('Country wise EconomicSupportIndex - Group 1',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('EconomicSupportIndex',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **EconomicSupportIndex_ForDisplay Group 2**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('India'),
    label='India',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Russia'),
    label='Russia'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('South Africa'),
    label='South Africa'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Turkey'),
    label='Turkey'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise EconomicSupportIndex - Group 2',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('EconomicSupportIndex',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **EconomicSupportIndex_ForDisplay Group 3**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Argentina'),
    label='Argentina',
    #color='deeppink'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Brazil'),
    label='Brazil'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Mexico'),
    label='Mexico'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise EconomicSupportIndex - Group 3',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('EconomicSupportIndex',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **EconomicSupportIndex_ForDisplay Group 4**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('France'),
    label='France',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Germany'),
    label='Germany'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Italy'),
    label='Italy'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('United Kingdom'),
    label='United Kingdom'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise EconomicSupportIndex - Group 4',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('EconomicSupportIndex',fontsize=12,fontweight='bold')
plt.show()

# %% [markdown]
# **EconomicSupportIndex_ForDisplay Group 5**

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=[10,5])

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('China'),
    label='China',
    color='Yellow'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Indonesia'),
    label='Indonesia'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('Japan'),
    label='Japan'
)

sns.lineplot(
    x='New_Date',
    y='EconomicSupportIndex_ForDisplay',
    data=df_con.get_group('South Korea'),
    label='South Korea'
)

plt.legend()
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.title('Country wise EconomicSupportIndex - Group 5',fontsize=12,fontweight='bold')
plt.xlabel('Date',fontsize=12,fontweight='bold')
plt.ylabel('EconomicSupportIndex',fontsize=12,fontweight='bold')
plt.show()
